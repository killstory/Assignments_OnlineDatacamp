# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input('Please input number: '))
if num == 0:
    print('เลขศูนย์')
elif num % 2 == 0 :
    print('เลขคู่')
else:
    print('เลขคี่')
# Out:
# Please input number: 117
# เลขคี่

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_1 = float(input('Please input your number: '))
num_2 = float(input('Please input your number: '))

while num_2 == 0:
    num_2 = float(input('Please input your number again: '))
print(num_1 // num_2)
# Out:
# Please input your number: 4
# Please input your number: 0
# Please input your number again: 2
# 2.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input('Please input your number: '))

count = 1
total = num

while num != 0:
    num = int(input('Please input your number: '))
    total += num
    count += 1
else:
    print (total // count)
# Out:
# Please input your number: 4
# Please input your number: 2
# Please input your number: 6
# Please input your number: 0
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input('Please input your number: '))
if num % 7 == 0:
    print('หาร 7 ลงตัว')
else:
    print('หาร 7 ไม่ลงตัว')
# Out:
# Please input your number: 117
# หาร 7 ไม่ลงตัว

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input('Please input ความยาวสามเหลี่ยมด้าน a: '))
b = int(input('Please input ความยาวสามเหลี่ยมด้าน b: '))
c = int(input('Please input ความยาวสามเหลี่ยมด้าน c: '))

if (a**2 == b**2 + c**2) | (b**2 == a**2 + c**2) | (c**2 == a**2 + b**2):
    print('สามารถนำมาสร้างสามเหลี่ยมมุฉากได้')
else:
    print('ไม่สามารถนำมาสร้างสามเหลี่ยมมุมฉากได้')
# Out:
# Please input ความยาวสามเหลี่ยมด้าน a: 3
# Please input ความยาวสามเหลี่ยมด้าน b: 4
# Please input ความยาวสามเหลี่ยมด้าน c: 5
# สามารถนำมาสร้างสามเหลี่ยมมุฉากได้

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input('Please input ความยาวสามเหลี่ยมด้าน a: '))
b = int(input('Please input ความยาวสามเหลี่ยมด้าน b: '))
c = int(input('Please input ความยาวสามเหลี่ยมด้าน c: '))
if (a**2 == (b**2 + c**2)) | (b**2 == (a**2 + c**2)) | (c**2 == (b**2 + a**2)):
    print("สามเหลี่ยมมุมฉาก")
elif (a**2 > (b**2 + c**2)) | (b**2 > (a**2 + c**2)) | (c**2 > (b**2 + a**2)):
    print("สามเหลี่ยมมุมป้าน")  
else:
    print("สามเหลี่ยมมุมแหลม")
# Out:
# Please input ความยาวสามเหลี่ยมด้าน a: 3
# Please input ความยาวสามเหลี่ยมด้าน b: 4
# Please input ความยาวสามเหลี่ยมด้าน c: 5
# สามเหลี่ยมมุมฉาก

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท')

a = int(input('ค่าอาหารครั้งที่หนึ่ง: '))
while (a < 1000)|(a > 5000):
    if (a < 1000)|(a > 5000):
        a = int(input('โปรดใส่ค่าอาหารครั้งที่หนึ่งอีกรอบ: '))
    
b = int(input('ค่าอาหารครั้งที่สอง: '))
while (b < 1000)|(b > 5000):
    if (b < 1000)|(b > 5000):
        b = int(input('โปรดใส่ค่าอาหารครั้งที่สองอีกรอบ: '))
    
c = int(input('ค่าอาหารครั้งที่สาม: '))
while (c < 1000)|(c > 5000):
    if (c < 1000)|(c > 5000):
        c = int(input('โปรดใส่ค่าอาหารครั้งที่สามอีกรอบ: '))
else:
    total = a + b + c 
    if total > 12000:
        total = total * 0.85
    elif total > 6000:
        total = total * 0.75
    print(total)
# Out:
# โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท
# ค่าอาหารครั้งที่หนึ่ง: 1
# โปรดใส่ค่าอาหารครั้งที่หนึ่งอีกรอบ: 1000
# ค่าอาหารครั้งที่สอง: 2
# โปรดใส่ค่าอาหารครั้งที่สองอีกรอบ: 5000
# ค่าอาหารครั้งที่สาม: 3
# โปรดใส่ค่าอาหารครั้งที่สามอีกรอบ: 4000
# 7500.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท')

a = int(input('ค่าอาหารครั้งที่หนึ่ง: '))
while (a < 1000)|(a > 5000):
    if (a < 1000)|(a > 5000):
        a = int(input('โปรดใส่ค่าอาหารครั้งที่หนึ่งอีกรอบ: '))
    
b = int(input('ค่าอาหารครั้งที่สอง: '))
while (b < 1000)|(b > 5000):
    if (b < 1000)|(b > 5000):
        b = int(input('โปรดใส่ค่าอาหารครั้งที่สองอีกรอบ: '))
    
c = int(input('ค่าอาหารครั้งที่สาม: '))
while (c < 1000)|(c > 5000):
    if (c < 1000)|(c > 5000):
        c = int(input('โปรดใส่ค่าอาหารครั้งที่สามอีกรอบ: '))

d = int(input('ค่าอาหารครั้งที่สี่: '))
while (d < 1000)|(d > 5000):
    if (d < 1000)|(d > 5000):
        d = int(input('โปรดใส่ค่าอาหารครั้งที่สี่อีกรอบ: '))
else:
    total = a + b + c 
    if total > 12000:
        d = d * 0.85
    elif total > 6000:
        d = d * 0.75
    print(d)
# Out:
# โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท
# ค่าอาหารครั้งที่หนึ่ง: 1000
# ค่าอาหารครั้งที่สอง: 5000
# ค่าอาหารครั้งที่สาม: 4000
# ค่าอาหารครั้งที่สี่: 5000
# 3750.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท')

a = int(input('ค่าอาหารครั้งที่หนึ่ง: '))
while (a < 1000)|(a > 5000):
    if (a < 1000)|(a > 5000):
        a = int(input('โปรดใส่ค่าอาหารครั้งที่หนึ่งอีกรอบ: '))
    
b = int(input('ค่าอาหารครั้งที่สอง: '))
while (b < 1000)|(b > 5000):
    if (b < 1000)|(b > 5000):
        b = int(input('โปรดใส่ค่าอาหารครั้งที่สองอีกรอบ: '))
    
c = int(input('ค่าอาหารครั้งที่สาม: '))
while (c < 1000)|(c > 5000):
    if (c < 1000)|(c > 5000):
        c = int(input('โปรดใส่ค่าอาหารครั้งที่สามอีกรอบ: '))

d = int(input('ค่าอาหารครั้งที่สี่: '))
while (d < 1000)|(d > 5000):
    if (d < 1000)|(d > 5000):
        d = int(input('โปรดใส่ค่าอาหารครั้งที่สี่อีกรอบ: '))
else:
    total = a + b + c 
    if total > 9000:
        d = d * 0.85
    elif total > 4000:
        d = d * 0.75
    print(d)
# Out:
# โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท
# ค่าอาหารครั้งที่หนึ่ง: 1000
# ค่าอาหารครั้งที่สอง: 5000
# ค่าอาหารครั้งที่สาม: 4000
# ค่าอาหารครั้งที่สี่: 5000
# 4250.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท')

credit = bool(input('มีบัตรเครดิตหรือไม่? True or False ?: '))

a = int(input('ค่าอาหารครั้งที่หนึ่ง: '))
while (a < 1000)|(a > 5000):
    if (a < 1000)|(a > 5000):
        a = int(input('โปรดใส่ค่าอาหารครั้งที่หนึ่งอีกรอบ: '))
    
b = int(input('ค่าอาหารครั้งที่สอง: '))
while (b < 1000)|(b > 5000):
    if (b < 1000)|(b > 5000):
        b = int(input('โปรดใส่ค่าอาหารครั้งที่สองอีกรอบ: '))
    
c = int(input('ค่าอาหารครั้งที่สาม: '))
while (c < 1000)|(c > 5000):
    if (c < 1000)|(c > 5000):
        c = int(input('โปรดใส่ค่าอาหารครั้งที่สามอีกรอบ: '))

d = int(input('ค่าอาหารครั้งที่สี่: '))
while (d < 1000)|(d > 5000):
    if (d < 1000)|(d > 5000):
        d = int(input('โปรดใส่ค่าอาหารครั้งที่สี่อีกรอบ: '))

else:
    total = a + b + c 
    if total > 9000:
        d = d * 0.70
    elif total > 4000:
        d = d * 0.75
    if credit == True:
        d = d * 0.95
    print(d)
# Out:
# โปรดใส่ค่าอาหารไม่ต่ำกว่า 1000 และไม่เกิน 5000 บาท
# มีบัตรเครดิตหรือไม่? True or False ?: False
# ค่าอาหารครั้งที่หนึ่ง: 1
# โปรดใส่ค่าอาหารครั้งที่หนึ่งอีกรอบ: 1000
# ค่าอาหารครั้งที่สอง: 5000
# ค่าอาหารครั้งที่สาม: 4000
# ค่าอาหารครั้งที่สี่: 5000
# 3325.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = input('Input alphabet with uppercase and lowercase minimum 7 characters: ')
result= ''
for i in text: 
    if i.isupper():
        result = result + i.lower()
    else:
        result = result + i.upper()
print(result)
# Out:
# Input alphabet with uppercase and lowercase minimum 7 characters: PrayuTtTt
# pRAYUtTtT

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text_1 = input('text no.1: ')
text_2 = input('text no.2: ')
text_3 = input('text no.3: ')
text_4 = input('text no.4: ')

words = [text_1, text_2, text_3, text_4,]
sorted(words, key=len)
# Out:
# text no.1: Kahn
# text no.2: met
# text no.3: Janny
# text no.4: Google
# ['met', 'Kahn', 'Janny', 'Google']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input('Please input hour number (0-60): '))
num2 = int(input('Please input minutes number (0-59): '))

print('The fare is: ', (num1*150) + (num2*2))
# Out:
# Please input hour number (0-60): 10
# Please input minutes number (0-59): 50
# The fare is:  1600

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input('Please input hour number (0-60): '))
num2 = int(input('Please input minutes number (0-59): '))

if num1 == 0:
    print("Free parking fare")

elif num1 == 1 and num2 < 15:
    print("Free parking fare")

elif num1 >1 and num2 <= 15:  
    print('The fare is: ', num1*300)

elif num1 >=1 and num2 > 15:
    print('The fare is: ', (num1*300) + 300)
# Out:
# Please input hour number (0-60): 1
# Please input minutes number (0-59): 14
# Free parking fare

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
total_heads = int(input('Total heads: '))
total_legs = int(input('Total legs: '))

bird = ((4**total_heads) - total_legs)//2
cow = ((2**total_heads) + total_legs)//2

print('pay tax: ', (150*bird) + (220*cow))
# Out:
# Total heads: 2
# Total legs: 6
# pay tax:  1850
